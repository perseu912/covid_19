# %%
#importando a biblioteca que vai trabalhar com os dados de data_science
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

#importando os dados da covid-19 
dados_petrolina = pd.read_csv('pet.csv',sep=',',error_bad_lines=False)
dados_petrolina.to_excel('pet.xlsx')
dados_petrolina = dados_petrolina.iloc[::-1]

#print(dados_petrolina)
#dados_petrolina.to_excel('petrolina.xlsx')
confirmados = dados_petrolina['last_available_confirmed']
#print(confirmados)



#plotando os dados de novos casos
ax = dados_petrolina.plot(x='date',y='new_confirmed',kind='bar')

casos_diarios = dados_petrolina['new_confirmed']

def calcSma(data, smaPeriod):
    j = next(i for i, x in enumerate(data) if x is not None)
    our_range = range(len(data))[j + smaPeriod - 1:]
    empty_list = [None] * (j + smaPeriod - 1)
    sub_result = [np.mean(data[i - smaPeriod + 1: i + 1]) for i in our_range]

    return np.array(empty_list + sub_result)

media = calcSma(casos_diarios,7)
plt.plot(dados_petrolina['date'],media,label='media móvel',c='black')
# Make most of the ticklabels empty so the labels don't get too crowded
ticklabels = ['']*len(dados_petrolina.index)
# Every 4th ticklable shows the month and day
ticklabels[::30] = dados_petrolina['date'][::30]
# Every 12th ticklabel includes the year
ax.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate()
print('covid-19 em Petrolina-PE')
plt.title('covid-19 em Petrolina-PE')
plt.savefig('plot_media_pet.png',dpi=800)
plt.show()
# Out:
# covid-19 em Petrolina-PE

# %%
casos_diarios = dados_petrolina['new_confirmed']


def calcSma(data, smaPeriod):
    j = next(i for i, x in enumerate(data) if x is not None)
    our_range = range(len(data))[j + smaPeriod - 1:]
    empty_list = [None] * (j + smaPeriod - 1)
    sub_result = [np.mean(data[i - smaPeriod + 1: i + 1]) for i in our_range]

    return np.array(empty_list + sub_result)

# %%
import numpy as np
media = calcSma(casos_diarios[-30:],6)
plt.bar(np.linspace(1,30,30),casos_diarios[-30:],label='casos diarios em Novembro')
plt.plot(np.linspace(1,30,30),media,label='media movel',c='black')
plt.xlabel('dia')
plt.ylabel('confirmados')
plt.legend()
plt.show()
import numpy as np
plt.bar(np.linspace(1,30,30),casos_diarios[-60:-30],label='casos diarios em Outubro')
plt.xlabel('dia')
plt.ylabel('confirmados')
plt.legend()
plt.show()
