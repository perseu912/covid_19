# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


#importando os dados do covid 19 em juazeiro
dados_jua = pd.read_csv('jua.csv',sep =',')
print(dados_jua)
dados_jua.to_excel('jua.xlsx')
# Out:
#      epidemiological_week        date  order_for_place state      city  \
# 0                      49  2020-11-29              252    BA  Juazeiro
# 1                      48  2020-11-28              251    BA  Juazeiro
# 2                      48  2020-11-27              250    BA  Juazeiro
# 3                      48  2020-11-26              249    BA  Juazeiro
# 4                      48  2020-11-25              248    BA  Juazeiro
# ..                    ...         ...              ...   ...       ...
# 247                    13  2020-03-27                5    BA  Juazeiro
# 248                    13  2020-03-26                4    BA  Juazeiro
# 249                    13  2020-03-25                3    BA  Juazeiro
# 250                    13  2020-03-24                2    BA  Juazeiro
# 251                    13  2020-03-23                1    BA  Juazeiro
#
#      city_ibge_code place_type  last_available_confirmed  \
# 0           2918407       city                      6957
# 1           2918407       city                      6957
# 2           2918407       city                      6905
# 3           2918407       city                      6891
# 4           2918407       city                      6851
# ..              ...        ...                       ...
# 247         2918407       city                         2
# 248         2918407       city                         2
# 249         2918407       city                         2
# 250         2918407       city                         2
# 251         2918407       city                         1
#
#      last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                       3188.91466              0
# 1                                       3188.91466             52
# 2                                       3165.07916             14
# 3                                       3158.66191             40
# 4                                       3140.32691             34
# ..                                             ...            ...
# 247                                        0.91675              0
# 248                                        0.91675              0
# 249                                        0.91675              0
# 250                                        0.91675              1
# 251                                        0.45837              1
#
#      last_available_deaths  new_deaths  last_available_death_rate  \
# 0                      126           0                     0.0181
# 1                      126           0                     0.0181
# 2                      126           1                     0.0182
# 3                      125           0                     0.0181
# 4                      125           0                     0.0182
# ..                     ...         ...                        ...
# 247                      0           0                     0.0000
# 248                      0           0                     0.0000
# 249                      0           0                     0.0000
# 250                      0           0                     0.0000
# 251                      0           0                     0.0000
#
#      estimated_population  is_last  is_repeated
# 0                  218162    False         True
# 1                  218162     True        False
# 2                  218162    False        False
# 3                  218162    False        False
# 4                  218162    False        False
# ..                    ...      ...          ...
# 247                218162    False        False
# 248                218162    False        False
# 249                218162    False        False
# 250                218162    False        False
# 251                218162    False        False
#
# [252 rows x 16 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


#importando os dados do covid 19 em juazeiro
dados_pet = pd.read_csv('pet.csv',sep =',')
print(dados_pet)
dados_pet.to_excel('pet.xlsx')
# Out:
#      epidemiological_week        date  order_for_place state       city  \
# 0                      49  2020-11-29              252    PE  Petrolina
# 1                      48  2020-11-28              251    PE  Petrolina
# 2                      48  2020-11-27              250    PE  Petrolina
# 3                      48  2020-11-26              249    PE  Petrolina
# 4                      48  2020-11-25              248    PE  Petrolina
# ..                    ...         ...              ...   ...        ...
# 247                    13  2020-03-27                5    PE  Petrolina
# 248                    13  2020-03-26                4    PE  Petrolina
# 249                    13  2020-03-25                3    PE  Petrolina
# 250                    13  2020-03-24                2    PE  Petrolina
# 251                    13  2020-03-23                1    PE  Petrolina
#
#      city_ibge_code place_type  last_available_confirmed  \
# 0           2611101       city                      8303
# 1           2611101       city                      8115
# 2           2611101       city                      7926
# 3           2611101       city                      7893
# 4           2611101       city                      7884
# ..              ...        ...                       ...
# 247         2611101       city                         2
# 248         2611101       city                         2
# 249         2611101       city                         2
# 250         2611101       city                         1
# 251         2611101       city                         1
#
#      last_available_confirmed_per_100k_inhabitants  new_confirmed  \
# 0                                       2343.38177            188
# 1                                       2290.32194            189
# 2                                       2236.97988             33
# 3                                       2227.66619              9
# 4                                       2225.12609             10
# ..                                             ...            ...
# 247                                        0.56447              0
# 248                                        0.56447              0
# 249                                        0.56447              1
# 250                                        0.28223              0
# 251                                        0.28223              1
#
#      last_available_deaths  new_deaths  last_available_death_rate  \
# 0                      114           0                     0.0137
# 1                      114           0                     0.0140
# 2                      114           0                     0.0144
# 3                      114           0                     0.0144
# 4                      114           2                     0.0145
# ..                     ...         ...                        ...
# 247                      0           0                     0.0000
# 248                      0           0                     0.0000
# 249                      0           0                     0.0000
# 250                      0           0                     0.0000
# 251                      0           0                     0.0000
#
#      estimated_population  is_last  is_repeated
# 0                  354317     True        False
# 1                  354317    False        False
# 2                  354317    False        False
# 3                  354317    False        False
# 4                  354317    False        False
# ..                    ...      ...          ...
# 247                354317    False        False
# 248                354317    False        False
# 249                354317    False        False
# 250                354317    False        False
# 251                354317    False        False
#
# [252 rows x 16 columns]

# %%
dados_jua = dados_jua.loc[::-1]
dados_jua.plot(x='date',y='new_confirmed')

# %%
dados_pet = dados_pet.loc[::-1]
dados_pet.plot(x='date',y='new_confirmed')

# %%
def calcSma(data, smaPeriod):
    j = next(i for i, x in enumerate(data) if x is not None)
    our_range = range(len(data))[j + smaPeriod - 1:]
    empty_list = [None] * (j + smaPeriod - 1)
    sub_result = [np.mean(data[i - smaPeriod + 1: i + 1]) for i in our_range]

    return np.array(empty_list + sub_result)

# %%
meses = ['janeiro','fevereiro','março','abril','maio','junho','julho','agosto','setembro','outubro','novembro','dezembro']
m_c = []
for dat in dados_jua['date']:
    dt = dat[5:7]
    #print(dt)
    m = meses[1*int(dt)-1]
    #print(m)
    m_c.append(m)
dados_jua['meses'] = m_c
dados_pet['meses'] = m_c
dados_jua.plot(x='meses',y='new_confirmed')

# %%
casos_diarios = dados_jua['new_confirmed']
media = calcSma(casos_diarios,7)

ax = dados_jua.plot(x='meses',y='new_confirmed',kind='bar',color='black')

plt.plot(dados_jua['date'],media,label='media móvel',c='red')
# Make most of the ticklabelhs empty so the labels don't get too crowded
ticklabels = ['']*len(dados_jua.index)
# Every 4th ticklable shows the month and day
ticklabels[::30] = dados_jua['meses'][::30]
# Every 12th ticklabel includes the year
ax.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate()
print('covid-19 em Juazeiro-Ba')
plt.ylabel('casos confirmados')
plt.title('covid-19 em Juazeiro')
plt.savefig('plot_media_movel_jua.png',dpi=800)
plt.show()
# Out:
# covid-19 em Juazeiro-Ba

# %%
casos_diarios = dados_pet['new_confirmed']
media = calcSma(casos_diarios,7)

ax = dados_pet.plot(x='meses',y='new_confirmed',kind='bar',color='black')

plt.plot(dados_pet['date'],media,label='media móvel',c='red')
# Make most of the ticklabelhs empty so the labels don't get too crowded
ticklabels = ['']*len(dados_pet.index)
# Every 4th ticklable shows the month and day
ticklabels[::30] = dados_pet['meses'][::30]
# Every 12th ticklabel includes the year
ax.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate()
print('covid-19 em Petrolina-PE')
plt.title('covid-19 em Petrolina')
plt.savefig('plot_media_movel_pet.png',dpi=800)
plt.show()
# Out:
# covid-19 em Petrolina-PE

# %%
import numpy as np
confirmados = dados_jua['last_available_confirmed']
#print(np.array(confirmados))
percent = (np.array(confirmados)[-1] - np.array(confirmados)[-30])/np.array(confirmados)[-30]

print(round(percent*100,2),'%')
media = calcSma(casos_diarios[-30:],6)
plt.bar(np.linspace(1,30,30),casos_diarios[-30:],label='casos diarios em Novembro')
plt.plot(np.linspace(1,30,30),media,label='media movel',c='black')
plt.xlabel('dia')
plt.ylabel('confirmados')
plt.legend()
plt.show()
import numpy as np
plt.bar(np.linspace(1,30,30),casos_diarios[-60:-30],label='casos diarios em Outubro')
media = calcSma(casos_diarios[-30:],6)
plt.plot(np.linspace(1,30,30),media,label='media movel',c='black')
plt.xlabel('dia')
plt.ylabel('confirmados')
plt.legend()
plt.show()
# Out:
# 16.03 %
