# %%
from scipy.integrate import odeint
from scipy import integrate, optimize
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# modelagem sir R0 em 8meses

# %%
casos_diarios = pd.read_csv('pet.csv',sep=',')['new_confirmed'].iloc[::-1]
y = casos_diarios

N = 430_000

def sir_model(y, x, beta, gamma):
    S = -beta * y[0] * y[1] / N
    R = gamma * y[1]
    I = -(S + R)
    return S, I, R

def fit_odeint(x, beta, gamma):
    return integrate.odeint(sir_model, (S0, I0, R0), x, args=(beta, gamma))[:,1]

def fit_(x,beta,gamma):
    return integrate.odeint(sir_,(S0,I0,R0),x,args=(beta,gamma))

I0=1
S0=N-i0
R0=0
C0=i0
D0=0

#REAL
plt.plot(t,y,label='real')

#fitagem completa  
x = np.linspace(0,len(y)+20,len(y)+20)
param,error=optimize.curve_fit(fit_odeint,t,y)
sirc=fit_(x,*param)
beta,gamma = param
# Out:
# /usr/lib/python3/dist-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-142f30ae094c> in <module>
#      30 #fitagem completa
#      31 x = np.linspace(0,len(y)+20,len(y)+20)
# ---> 32 param,error=optimize.curve_fit(fit_odeint,t,y)
#      33 sirc=fit_(x,*param)
#      34 beta,gamma = param
#
# /usr/lib/python3/dist-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     787         cost = np.sum(infodict['fvec'] ** 2)
#     788         if ier not in [1, 2, 3, 4]:
# --> 789             raise RuntimeError("Optimal parameters not found: " + errmsg)
#     790     else:
#     791         # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 600.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, optimize

confirmados = pd.read_csv('pet.csv',sep=',')['last_available_confirmed'].iloc[::-1]
y = confirmados
t = np.linspace(0,len(y),len(y))

N = 430_000

ydata = np.array(y, dtype=float)/N
xdata = np.array(t, dtype=float)

def sir_model(y, x, beta, gamma):
    S = -beta * y[0] * y[1] / N
    R = gamma * y[1]
    I = -(S + R)
    C = I+R
   # I = gamma*y[1]
    return S, I, R, C

def fit_odeint(x, beta, gamma):
    return integrate.odeint(sir_model, (S0, I0, R0, C0), x, args=(beta, gamma))[:,3]

N = 1.0
I0 = ydata[0]
S0 = N - I0
R0 = 0.0
C0 = I0

popt, pcov = optimize.curve_fit(fit_odeint, xdata, ydata)
fitted = fit_odeint(xdata, *popt)

beta, gamma = popt

plt.plot(xdata, ydata, 'o',label='casos confirmados reais')
plt.plot(xdata, fitted,label=f'casos confir. fit. \n ß={round(beta,4)}  γ={round(gamma,4)} \n R0={round(beta/gamma,4)}')
plt.legend()
plt.savefig(f'model_fit_R0_{round(beta/gamma,4)}_.png',dpi=800)
plt.show()

# %%
t = np.linspace(0,len(y),len(y))
# The SIR model differential equations.
def deriv(y, t, N, beta, gamma):
    S, I, R = y
    dSdt = -beta * S * I / N
    dIdt = beta * S * I / N - gamma * I
    dRdt = gamma * I
    return dSdt, dIdt, dRdt

# Initial conditions vector
y0 = S0, I0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(N, beta, gamma))
S, I, R = ret.T

#plt.plot(t,S,label='sucetivel')
plt.plot(t,I,label='infectados')
plt.plot(t,R,label='recuperados')
plt.show()

# %%
#curva 1  
x= np.linspace(0,len(y),(len(y)))
param,error=optimize.curve_fit(fit_edo,t[:85],y[:85])
sirc=fit_(x,*param)
beta1,gamma1 = param
fitado_1=fit_edo(x,beta1,gamma11)
plt.plot(x,fitado_1,label=f'1 isolamento social [beta={round(beta1,3)};gamma={round(gamma1,3)};R={round(beta1/gamma1,3)};alpha={round(beta1,3)}]')
plt.legend()
plt.show()

i0=y[70]
s0=N-i0
r0=97
c0=i0
d0
# Out:
# /usr/lib/python3/dist-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-367dbe2544b9> in <module>
#       2 x= np.linspace(0,len(y),(len(y)))
#       3 param,error=optimize.curve_fit(fit_edo,t[:85],y[:85])
# ----> 4 sirc=fit_(x,*param)
#       5 beta1,gamma1 = param
#       6 fitado_1=fit_edo(x,beta1,gamma11)
#
# TypeError: fit_() takes 3 positional arguments but 4 were given
