# %%
from scipy.integrate import odeint
from scipy import integrate, optimize
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# modelagem sir R0 em 8meses

# %%
casos_diarios = pd.read_csv('pet.csv',sep=',')['new_confirmed'].iloc[::-1]
y = casos_diarios

N = 430_000

def sir_model(y, x, beta, gamma):
    S = -beta * y[0] * y[1] / N
    R = gamma * y[1]
    I = -(S + R)
    return S, I, R

def fit_odeint(x, beta, gamma):
    return integrate.odeint(sir_model, (S0, I0, R0), x, args=(beta, gamma))[:,1]

def fit_(x,beta,gamma):
    return integrate.odeint(sir_,(S0,I0,R0),x,args=(beta,gamma))

I0=1
S0=N-I0
R0=0
C0=I0
D0=0

#REAL
plt.plot(t,y,label='real')

#fitagem completa  
x = np.linspace(0,len(y)+20,len(y)+20)
param,error=optimize.curve_fit(fit_odeint,t,y)
sirc=fit_(x,*param)
beta,gamma = param
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# <ipython-input-4-dab968bf97df> in <module>
#      23
#      24 #REAL
# ---> 25 plt.plot(t,y,label='real')
#      26
#      27 #fitagem completa
#
# NameError: name 't' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, optimize

confirmados = pd.read_csv('pet.csv',sep=',')['last_available_confirmed'].iloc[::-1]
y = confirmados
t = np.linspace(0,len(y),len(y))

N=354_317

ydata = np.array(y, dtype=float)/N
xdata = np.array(t, dtype=float)

def sir_model(y, x, beta, gamma):
    S = -beta * y[0] * y[1] / N
    R = gamma * y[1]
    I = -(S + R)
    #I =( beta*y[0]*y[1] / N ) - y[1]*alpha
    C = I+R
   # I = gamma*y[1]
    return S, I, R, C

def fit_odeint(x, beta, gamma):
    return integrate.odeint(sir_model, (S0, I0, R0, C0), x, args=(beta, gamma))[:,3]

N = 1.0
I0 = ydata[0]
S0 = N - I0
R0 = 0.0
C0 = I0

popt, pcov = optimize.curve_fit(fit_odeint, xdata, ydata)
fitted = fit_odeint(xdata, *popt)

beta, gamma = popt

plt.plot(xdata, ydata, 'o',label='casos confirmados reais')
plt.plot(xdata, fitted,label=f'casos confir. fit. \n ß={round(beta,4)}  γ={round(gamma,4)} \n R0={round(beta/gamma,4)}')
plt.legend()
plt.savefig(f'model_fit_R0_{round(beta/gamma,4)}_.png',dpi=800)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, optimize

confirmados = pd.read_csv('pet.csv',sep=',')['last_available_confirmed'].iloc[::-1]
y = confirmados
t = np.linspace(0,len(y),len(y))
N = 354_317

ydata = np.array(y, dtype=float)/N
xdata = np.array(t, dtype=float)

def sir_model(y, x, beta, gamma, alpha):
    S = -beta * y[0] * y[1] / N
    R = (gamma) * y[1]
    D = alpha*y[1]
    I =( beta*y[0]*y[1] / N ) - y[1]*alpha
    #C = I+R
    #I = -(S + R)
    C = R+D
   #I = gamma*y[1]
    return S, I, R, D, C

def fit_odeint(x, beta, gamma, alpha):
    return integrate.odeint(sir_model, (S0, I0, R0, D0, C0), x, args=(beta, gamma,alpha))[:,4]

N = 1.0
I0 = ydata[0]
S0 = N - I0
R0 = 0.0
C0 = I0
D0 = 0.

popt, pcov = optimize.curve_fit(fit_odeint, xdata, ydata)
fitted = fit_odeint(xdata, *popt)
print(pcov)

#be


beta, gamma, alpha = popt

plt.plot(xdata, ydata, 'o',label='casos confirmados reais')
plt.plot(xdata, fitted,label=f'casos confir. fit. \n ß={round(beta,4)}  γ={round(gamma,4)} \n R0={round(beta/gamma,4)} ')
plt.legend()
plt.savefig(f'model_fit_R0_{round(beta/gamma,4)}_.png',dpi=800)
plt.show()
# Out:
# [[0.0057562  0.00887904 0.0058263 ]
#  [0.00887904 0.01649291 0.00901199]
#  [0.0058263  0.00901199 0.00589748]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, optimize

confirmados = pd.read_csv('pet.csv',sep=',')['last_available_confirmed'].iloc[::-1][:30]
y = confirmados
t = np.linspace(0,len(y),len(y))
N = 354_317

ydata = np.array(y, dtype=float)/N
xdata = np.array(t, dtype=float)

def sir_model(y, x, beta, gamma, alpha):
    S = -beta * y[0] * y[1] / N
    R = (gamma) * y[1]
    D = alpha*y[1]
    I =( beta*y[0]*y[1] / N ) - y[1]*alpha
    #C = I+R
    #I = -(S + R)
    C = R+D
   #I = gamma*y[1]
    return S, I, R, D, C

def fit_odeint(x, beta, gamma, alpha):
    return integrate.odeint(sir_model, (S0, I0, R0, D0, C0), x, args=(beta, gamma,alpha))[:,4]

N = 1.0
I0 = ydata[0]
S0 = N - I0
R0 = 0.0
C0 = I0
D0 = 0.

popt, pcov = optimize.curve_fit(fit_odeint, xdata, ydata)
fitted = fit_odeint(xdata, *popt)
print(pcov)

#be


beta, gamma, alpha = popt

plt.plot(xdata, ydata, 'o',label='casos confirmados reais')
plt.plot(xdata, fitted,label=f'casos confir. fit. \n ß={round(beta,4)}  γ={round(gamma,4)} \n R0={round(beta/gamma,4)} ')
plt.legend()
plt.savefig(f'model_fit_R0_{round(beta/gamma,4)}_.png',dpi=800)
plt.show()
# Out:
# [[ 10.12946039 -10.19114798  10.21779451]
#  [-10.19114798  10.25359887 -10.28085448]
#  [ 10.21779451 -10.28085448  10.30871119]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, optimize

confirmados = pd.read_csv('pet.csv',sep=',')['last_available_confirmed'].iloc[::-1][30:60]
y = confirmados
t = np.linspace(0,len(y),len(y))
N = 354_317

ydata = np.array(y, dtype=float)/N
xdata = np.array(t, dtype=float)

def sir_model(y, x, beta, gamma, alpha):
    S = -beta * y[0] * y[1] / N
    R = (gamma) * y[1]
    D = alpha*y[1]
    I =( beta*y[0]*y[1] / N ) - y[1]*alpha
    #C = I+R
    #I = -(S + R)
    C = R+D
   #I = gamma*y[1]
    return S, I, R, D, C

def fit_odeint(x, beta, gamma, alpha):
    return integrate.odeint(sir_model, (S0, I0, R0, D0, C0), x, args=(beta, gamma,alpha))[:,4]

N = 1.0
I0 = ydata[0]
S0 = N - I0
R0 = 0.0
C0 = I0
D0 = 0.

popt, pcov = optimize.curve_fit(fit_odeint, xdata, ydata)
fitted = fit_odeint(xdata, *popt)
print(pcov)

#be


beta, gamma, alpha = popt

plt.plot(xdata, ydata, 'o',label='casos confirmados reais')
plt.plot(xdata, fitted,label=f'casos confir. fit. \n ß={round(beta,4)}  γ={round(gamma,4)} \n R0={round(beta/(gamma+alpha),4)} ')
plt.legend()
plt.savefig(f'model_fit_R0_{round(beta/gamma,4)}_.png',dpi=800)
plt.show()
# Out:
# [[ 4.88737536e+19 -2.38625937e+20 -4.21630685e+19]
#  [-2.26132264e+20  1.25683130e+21  2.68447933e+20]
#  [-3.61620736e+19  2.49926306e+20  6.64357095e+19]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, optimize

confirmados = pd.read_csv('pet.csv',sep=',')['last_available_confirmed'].iloc[::-1][60:90]
y = confirmados
t = np.linspace(0,len(y),len(y))
N = 354_317

ydata = np.array(y, dtype=float)/N
xdata = np.array(t, dtype=float)

def sir_model(y, x, beta, gamma, alpha):
    S = -beta * y[0] * y[1] / N
    R = (gamma) * y[1]
    D = alpha*y[1]
    I =( beta*y[0]*y[1] / N ) - y[1]*alpha
    #C = I+R
    #I = -(S + R)
    C = R+D
   #I = gamma*y[1]
    return S, I, R, D, C

def fit_odeint(x, beta, gamma, alpha):
    return integrate.odeint(sir_model, (S0, I0, R0, D0, C0), x, args=(beta, gamma,alpha))[:,4]

N = 1.0
I0 = ydata[0]
S0 = N - I0
R0 = 0.0
C0 = I0
D0 = 0.

popt, pcov = optimize.curve_fit(fit_odeint, xdata, ydata)
fitted = fit_odeint(xdata, *popt)
print(pcov)

#be


beta, gamma, alpha = popt

plt.plot(xdata, ydata, 'o',label='casos confirmados reais')
plt.plot(xdata, fitted,label=f'casos confir. fit. \n ß={round(beta,4)}  γ={round(gamma,4)} \n R0={round(beta/(gamma+alpha),4)} ')
plt.legend()
plt.savefig(f'model_fit_R0_{round(beta/gamma,4)}_.png',dpi=800)
plt.show()
# Out:
# [[ 0.97344909 -0.97021026  0.95467697]
#  [-0.97021026  0.96708425 -0.95164608]
#  [ 0.95467697 -0.95164608  0.93647609]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, optimize

confirmados = pd.read_csv('pet.csv',sep=',')['last_available_confirmed'].iloc[::-1][90:120]
y = confirmados
t = np.linspace(0,len(y),len(y))
N = 354_317

ydata = np.array(y, dtype=float)/N
xdata = np.array(t, dtype=float)

def sir_model(y, x, beta, gamma, alpha):
    S = -beta * y[0] * y[1] / N
    R = (gamma) * y[1]
    D = alpha*y[1]
    I =( beta*y[0]*y[1] / N ) - y[1]*alpha
    #C = I+R
    #I = -(S + R)
    C = R+D
   #I = gamma*y[1]
    return S, I, R, D, C

def fit_odeint(x, beta, gamma, alpha):
    return integrate.odeint(sir_model, (S0, I0, R0, D0, C0), x, args=(beta, gamma,alpha))[:,4]

N = 1.0
I0 = ydata[0]
S0 = N - I0
R0 = 0.0
C0 = I0
D0 = 0.

popt, pcov = optimize.curve_fit(fit_odeint, xdata, ydata)
fitted = fit_odeint(xdata, *popt)
print(pcov)

#be


beta, gamma, alpha = popt

plt.plot(xdata, ydata, 'o',label='casos confirmados reais')
plt.plot(xdata, fitted,label=f'casos confir. fit. \n ß={round(beta,4)}  γ={round(gamma,4)} \n R0={round(beta/(gamma+alpha),4)} ')
plt.legend()
plt.savefig(f'model_fit_R0_{round(beta/gamma,4)}_.png',dpi=800)
plt.show()
# Out:
# [[ 0.14796531 -0.14141359  0.140796  ]
#  [-0.14141359  0.13515491 -0.13456719]
#  [ 0.140796   -0.13456719  0.13398462]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, optimize

confirmados = pd.read_csv('pet.csv',sep=',')['last_available_confirmed'].iloc[::-1][120:150]
y = confirmados
t = np.linspace(0,len(y),len(y))
N = 354_317

ydata = np.array(y, dtype=float)/N
xdata = np.array(t, dtype=float)

def sir_model(y, x, beta, gamma, alpha):
    S = -beta * y[0] * y[1] / N
    R = (gamma) * y[1]
    D = alpha*y[1]
    I =( beta*y[0]*y[1] / N ) - y[1]*alpha
    #C = I+R
    #I = -(S + R)
    C = R+D
   #I = gamma*y[1]
    return S, I, R, D, C

def fit_odeint(x, beta, gamma, alpha):
    return integrate.odeint(sir_model, (S0, I0, R0, D0, C0), x, args=(beta, gamma,alpha))[:,4]

N = 1.0
I0 = ydata[0]
S0 = N - I0
R0 = 0.0
C0 = I0
D0 = 0.

popt, pcov = optimize.curve_fit(fit_odeint, xdata, ydata)
fitted = fit_odeint(xdata, *popt)
print(pcov)

#be


beta, gamma, alpha = popt

plt.plot(xdata, ydata, 'o',label='casos confirmados reais')
plt.plot(xdata, fitted,label=f'casos confir. fit. \n ß={round(beta,4)}  γ={round(gamma,4)} \n R0={round(beta/(gamma+alpha),4)} ')
plt.legend()
plt.savefig(f'model_fit_R0_{round(beta/gamma,4)}_.png',dpi=800)
plt.show()
# Out:
# [[ 0.01378951 -0.01166464  0.0110676 ]
#  [-0.01166464  0.00989719 -0.00941198]
#  [ 0.0110676  -0.00941198  0.00896653]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, optimize

confirmados = pd.read_csv('pet.csv',sep=',')['last_available_confirmed'].iloc[::-1][150:180]
y = confirmados
t = np.linspace(0,len(y),len(y))
N = 354_317

ydata = np.array(y, dtype=float)/N
xdata = np.array(t, dtype=float)

def sir_model(y, x, beta, gamma, alpha):
    S = -beta * y[0] * y[1] / N
    R = (gamma) * y[1]
    D = alpha*y[1]
    I =( beta*y[0]*y[1] / N ) - y[1]*alpha
    #C = I+R
    #I = -(S + R)
    C = R+D
   #I = gamma*y[1]
    return S, I, R, D, C

def fit_odeint(x, beta, gamma, alpha):
    return integrate.odeint(sir_model, (S0, I0, R0, D0, C0), x, args=(beta, gamma,alpha))[:,4]

N = 1.0
I0 = ydata[0]
S0 = N - I0
R0 = 0.0
C0 = I0
D0 = 0.

popt, pcov = optimize.curve_fit(fit_odeint, xdata, ydata)
fitted = fit_odeint(xdata, *popt)
print(pcov)

#be


beta, gamma, alpha = popt

plt.plot(xdata, ydata, 'o',label='casos confirmados reais')
plt.plot(xdata, fitted,label=f'casos confir. fit. \n ß={round(beta,4)}  γ={round(gamma,4)} \n R0={round(beta/(gamma+alpha),4)} ')
plt.legend()
plt.savefig(f'model_fit_R0_{round(beta/gamma,4)}_.png',dpi=800)
plt.show()
# Out:
# [[ 0.00267949 -0.00123194  0.00119671]
#  [-0.00123194  0.00111837 -0.00112551]
#  [ 0.00119671 -0.00112551  0.00113411]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, optimize

confirmados = pd.read_csv('pet.csv',sep=',')['last_available_confirmed'].iloc[::-1][180:210]
y = confirmados
t = np.linspace(0,len(y),len(y))
N = 354_317

ydata = np.array(y, dtype=float)/N
xdata = np.array(t, dtype=float)

def sir_model(y, x, beta, gamma, alpha):
    S = -beta * y[0] * y[1] / N
    R = (gamma) * y[1]
    D = alpha*y[1]
    I =( beta*y[0]*y[1] / N ) - y[1]*alpha
    #C = I+R
    #I = -(S + R)
    C = R+D
   #I = gamma*y[1]
    return S, I, R, D, C

def fit_odeint(x, beta, gamma, alpha):
    return integrate.odeint(sir_model, (S0, I0, R0, D0, C0), x, args=(beta, gamma,alpha))[:,4]

N = 1.0
I0 = ydata[0]
S0 = N - I0
R0 = 0.0
C0 = I0
D0 = 0.

popt, pcov = optimize.curve_fit(fit_odeint, xdata, ydata)
fitted = fit_odeint(xdata, *popt)
print(pcov)

#be


beta, gamma, alpha = popt

plt.plot(xdata, ydata, 'o',label='casos confirmados reais')
plt.plot(xdata, fitted,label=f'casos confir. fit. \n ß={round(beta,4)}  γ={round(gamma,4)} \n R0={round(beta/(gamma+alpha),4)} ')
plt.legend()
plt.savefig(f'model_fit_R0_{round(beta/gamma,4)}_.png',dpi=800)
plt.show()
# Out:
# [[ 0.00433143 -0.00241175  0.00237945]
#  [-0.00241175  0.00150481 -0.00149187]
#  [ 0.00237945 -0.00149187  0.00147933]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, optimize

confirmados = pd.read_csv('pet.csv',sep=',')['last_available_confirmed'].iloc[::-1][210:240]
y = confirmados
t = np.linspace(0,len(y),len(y))
N = 354_317

ydata = np.array(y, dtype=float)/N
xdata = np.array(t, dtype=float)

def sir_model(y, x, beta, gamma, alpha):
    S = -beta * y[0] * y[1] / N
    R = (gamma) * y[1]
    D = alpha*y[1]
    I =( beta*y[0]*y[1] / N ) - y[1]*alpha
    #C = I+R
    #I = -(S + R)
    C = R+D
   #I = gamma*y[1]
    return S, I, R, D, C

def fit_odeint(x, beta, gamma, alpha):
    return integrate.odeint(sir_model, (S0, I0, R0, D0, C0), x, args=(beta, gamma,alpha))[:,4]

N = 1.0
I0 = ydata[0]
S0 = N - I0
R0 = 0.0
C0 = I0
D0 = 0.

popt, pcov = optimize.curve_fit(fit_odeint, xdata, ydata)
fitted = fit_odeint(xdata, *popt)
print(pcov)

#be


beta, gamma, alpha = popt

plt.plot(xdata, ydata, 'o',label='casos confirmados reais')
plt.plot(xdata, fitted,label=f'casos confir. fit. \n ß={round(beta,4)}  γ={round(gamma,4)} \n R0={round(beta/(gamma+alpha),4)} ')
plt.legend()
plt.savefig(f'model_fit_R0_{round(beta/gamma,4)}_.png',dpi=800)
plt.show()
# Out:
# [[ 0.01870479 -0.01771264  0.0176354 ]
#  [-0.01771264  0.0167828  -0.0167105 ]
#  [ 0.0176354  -0.0167105   0.0166386 ]]

# %%
t = np.linspace(0,len(y),len(y))
# The SIR model differential equations.
def deriv(y, t, N, beta, gamma,alpha):
    S, I, R, D = y
    dSdt = -beta * S * I / N
    dIdt = beta * S * I / N - gamma * I
    dRdt = gamma * I
    dDdt = alpha*I
    return dSdt, dIdt, dRdt, dDdt

# Initial conditions vector
y0 = S0, I0, R0, D0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(N, beta, gamma,alpha))
S, I, R, D = ret.T*354_327

#plt.plot(t,S,label='sucetivel')
plt.plot(t,I,label='infectados')
plt.plot(t,D,label='mortos')
plt.plot(t,R,label='recuperados')
plt.legend()
plt.show()

# %%
#curva 1  
x= np.linspace(0,len(y),(len(y)))
param,error=optimize.curve_fit(fit_edo,t[:85],y[:85])
sirc=fit_(x,*param)
beta1,gamma1 = param
fitado_1=fit_edo(x,beta1,gamma11)
plt.plot(x,fitado_1,label=f'1 isolamento social [beta={round(beta1,3)};gamma={round(gamma1,3)};R={round(beta1/gamma1,3)};alpha={round(beta1,3)}]')
plt.legend()
plt.show()

i0=y[70]
s0=N-i0
r0=97
c0=i0
d0
