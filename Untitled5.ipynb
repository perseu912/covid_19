# %%
city = 'juazeiro'

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


dados_pet = pd.read_csv(f'dados_{city}.csv',sep=',')
#dados_pet.plot()

confirmados = dados_pet['last_available_confirmed'][::-1]
mortos = dados_pet['last_available_deaths'][::-1]
casos_diarios = dados_pet['new_confirmed'][::-1]
mortes_diarias = dados_pet['new_deaths'][::-1]


meses = ['jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']
date = dados_pet['date'][::-1]
date = [i[4:] for i in date]
print(int(date[0][2:3]))
date = [('/').join([i[4:],meses[int(i[1:3])-1]]) for i in date]
date




dados = {'confirmados':np.array(confirmados),
         'mortos':np.array(mortos),
         'mortes_diarias':np.array(mortes_diarias),
         'casos_diarios':np.array(casos_diarios),
         'date':date}
dados = pd.DataFrame(dados,index=date)
dados.to_excel(f'dados_{city}.xlsx')
dados





#


def calcSma(data, smaPeriod):
    j = next(i for i, x in enumerate(data) if x is not None)
    our_range = range(len(data))[j + smaPeriod - 1:]
    empty_list = [None] * (j + smaPeriod - 1)
    sub_result = [np.mean(data[i - smaPeriod + 1: i + 1]) for i in our_range]

    return np.array(empty_list + sub_result)


ax = dados.plot(x='date',y='casos_diarios',kind='bar',color='black')

media = calcSma(casos_diarios,7)
plt.plot(dados['date'],media,label='media móvel',c='red')

# Make most of the ticklabels empty so the labels don't get too crowded
ticklabels = ['']*len(dados.index)
# Every 4th ticklable shows the month and day
ticklabels[::20] = dados['date'][::20]
# Every 12th ticklabel includes theear
ax.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate()
print(f'covid-19 em {city}')
plt.legend()
plt.xlabel('data')
plt.ylabel('numero de pessoas')
plt.title(f'casos diarios em covid-19 em {city}')
plt.savefig(f'plot_media_{city}.jpg',dpi=800)
plt.show()
# Out:
# 3
# covid-19 em juazeiro

# %%
dados.plot(x='date',y='confirmados',kind='line',color='black')

#media = calcSma(casos_diarios,7)
#plt.plot(dados['date'],media,label='media móvel',c='red')

# Make most of the ticklabels empty so the labels don't get too crowded
ticklabels = ['']*len(dados.index)
# Every 4th ticklable shows the month and day
ticklabels[::15] = dados['date'][::15]
# Every 12th ticklabel includes theear
ax.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate()
print(f'covid-19 em {city}')
plt.legend()
plt.grid()
plt.xlabel('data')
plt.ylabel('numero de pessoas')
plt.title(f'casos confirmados em covid-19 em {city}')
plt.savefig(f'plot_casos_media_{city}.jpg',dpi=800)
plt.show()
# Out:
# covid-19 em juazeiro

# %%
ax = dados.plot(x='date',y='mortes_diarias',kind='bar',color='black')

media = calcSma(mortes_diarias,7)
plt.plot(dados['date'],media,label='media móvel',c='red')

# Make most of the ticklabels empty so the labels don't get too crowded
ticklabels = ['']*len(dados.index)
# Every 4th ticklable shows the month and day
ticklabels[::20] = dados['date'][::20]
# Every 12th ticklabel includes theear
ax.xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate()
print(f'covid-19 em {city}')
plt.legend()
plt.xlabel('data')
plt.ylabel('numero de pessoas')
plt.title(f'mortes diarias em covid-19 em {city}')
plt.savefig(f'plot_mortes_media_{city}.jpg',dpi=800)
plt.show()
# Out:
# covid-19 em juazeiro

# %%
dados[-30:].plot(y=['casos_diarios'],kind='bar',color='black')
media = calcSma(dados['casos_diarios'][-30:],7)
plt.plot(dados['date'][-30:],media,label='média movel',c='red')
plt.legend()
plt.show()

# %%
import os
cls = os.system('clear')
from IPython.display import clear_output
cls = clear_output(wait=True)

filenames = []
total = len(dados.index)
for i in range(1,total):
    cls
    ax = dados[:i].plot(x='date',y='confirmados')
    filename = f'gif/img{i}.png'
    filenames.append(filename)
    print(f'{round((i/total)*100,2)}% concluidos',flush=True)
    plt.savefig(filename)

import imageio

import imageio
images = []
for filename in filenames:
    images.append(imageio.imread(filename))
imageio.mimsave('gif/movie.gif', images)
# Out:
# 0.31% concluidos
# 0.63% concluidos
# 0.94% concluidos
# 1.25% concluidos
# 1.57% concluidos
# 1.88% concluidos
# 2.19% concluidos
# 2.51% concluidos
# 2.82% concluidos
# 3.13% concluidos
# 3.45% concluidos
# 3.76% concluidos
# 4.08% concluidos
# 4.39% concluidos
# 4.7% concluidos
# 5.02% concluidos
# 5.33% concluidos
# 5.64% concluidos
# 5.96% concluidos
# 6.27% concluidos
# 6.58% concluidos
# /usr/lib/python3/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# 6.9% concluidos
# 7.21% concluidos
# 7.52% concluidos
# 7.84% concluidos
# 8.15% concluidos
# 8.46% concluidos
# 8.78% concluidos
# 9.09% concluidos
# 9.4% concluidos
# 9.72% concluidos
# 10.03% concluidos
# ...

# %%
# Out:
#         confirmados  mortos  casos_diarios
# 23/mar            1       0              1
# 24/mar            1       0              0
# 25/mar            2       0              1
# 26/mar            2       0              0
# 27/mar            2       0              0
# ...             ...     ...            ...
# 11/jan        12204     136            460
# 12/jan        12371     138            167
# 13/jan        12371     138              0
# 14/jan        12755     138            384
# 15/jan        12935     138            180
#
# [299 rows x 3 columns]

# %%
clear

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import PillowWriter

fig = plt.figure()

def animate(nframe):
      plt.cla()
      plt.plot(dados['date'][:nframe], np.array(dados['confirmados'])[:nframe])
      plt.ylim(0,1)
      plt.title('Exp: %.2f'%(1.*nframe/10.))
        

anim = animation.FuncAnimation(fig, animate, frames=30)
anim.save('demoanimation.gif', writer='imagemagick', fps=4);
# Out:
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
